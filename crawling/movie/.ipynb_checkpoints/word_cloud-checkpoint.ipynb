# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud
from konlpy.tag import Kkma
kkma = Kkma()
# Out:
# C:\Users\wjrmf\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
text = open('ok.txt','r',-1,"utf-8").read()

wordcloud = WordCloud().generate(text)

# %%
wordcloud.words_
# Out:
# {'영화': 1.0,
#  '조커가': 0.6361581920903955,
#  '너무': 0.5774011299435028,
#  '조커': 0.5242937853107345,
#  '진짜': 0.5186440677966102,
#  '정말': 0.47570621468926555,
#  '조커의': 0.39887005649717516,
#  '조커는': 0.3389830508474576,
#  '조커를': 0.3333333333333333,
#  '영화는': 0.31864406779661014,
#  '연기': 0.29717514124293787,
#  '그냥': 0.29265536723163843,
#  '영화를': 0.2768361581920904,
#  '영화가': 0.23389830508474577,
#  '있는': 0.21468926553672316,
#  '호아킨 피닉스의': 0.21016949152542372,
#  '없는': 0.20903954802259886,
#  '그리고': 0.20451977401129945,
#  '보고': 0.18757062146892656,
#  '최고의': 0.17853107344632768,
#  '이렇게': 0.17627118644067796,
#  '내가': 0.17401129943502824,
#  '연기가': 0.17175141242937852,
#  '가장': 0.15141242937853108,
#  '같은': 0.14915254237288136,
#  '하지만': 0.14350282485875707,
#  '그의': 0.1367231638418079,
#  '하는': 0.1367231638418079,
#  '호아킨': 0.13559322033898305,
#  '미쳤다': 0.1344632768361582,
#  '미친': 0.1344632768361582,
#  '보는 내내': 0.1344632768361582,
#  '같다': 0.12768361581920903,
# ...

# %%
import nltk
from konlpy.corpus import kolaw
from konlpy.tag import Okt; t = Okt()

# %%
tokens = t.nouns(text)
tokens
# Out:
# ['계단',
#  '포기',
#  '때',
#  '역대',
#  '조커',
#  '시저',
#  '로메',
#  '잭니콜슨',
#  '로저',
#  '스톤',
#  '버너',
#  '히스',
#  '레저',
#  '박명수',
#  '호아킨',
#  '피닉스',
#  '명작',
#  '골',
#  '번역',
#  '박지훈',
#  '대의',
#  '조커',
#  '조커',
#  '분장',
#  '후',
#  '계단',
#  '씬',
#  '린다',
#  '마블',
#  '공',
#  '노스',
#  '로',
#  '관객',
#  '열광',
#  '똥',
#  '조커',
#  '하나로',
#  '다시',
#  '부활',
#  '친구',
#  '이마',
#  '입맞춤',
#  '수',
#  '사과',
#  '그',
#  '마지막',
#  '순간',
#  '나락',
#  '인간',
#  '손',
#  '아무',
#  '때',
#  '그',
#  '손',
#  '광기',
#  '봉오동전투',
#  '점',
#  '조커',
#  '점',
#  '김현수',
#  '평론가',
#  '누구',
#  '연기',
#  '스토리',
#  '장면',
#  '음악',
#  '압권임',
#  '진짜',
#  '세',
#  '영등위',
#  '정신',
#  '마지막',
#  '조커',
#  '정신',
#  '영화',
#  '임',
#  '번역',
#  '오류',
#  '정작',
#  '편지',
#  '장면',
#  '핵심',
#  '단어',
#  '조커',
#  '배트맨',
#  '날',
#  '갠',
#  '히스',
#  '레저',
#  '생각',
#  '누구',
#  '사람',
#  '조커',
#  '괴물',
#  '수',
#  '영화',
#  '왜',
#  '미국',
#  '난리',
#  '이해',
#  '후반',
#  '부',
#  '조커',
#  '계단',
#  '씬',
#  '영화',
#  '인생',
#  '단연',
#  '베스트',
#  '적',
#  '미국',
# ...

# %%
# 1글자 제거
tokens = [word for word in tokens if len(word) > 1]

# %%
word = nltk.Text(tokens, name='영화 리뷰')
word.vocab().most_common(1000)
# Out:
# [('영화', 4736),
#  ('조커', 3951),
#  ('연기', 2067),
#  ('호아킨', 1146),
#  ('피닉스', 870),
#  ('사람', 829),
#  ('최고', 818),
#  ('진짜', 752),
#  ('생각', 677),
#  ('정말', 560),
#  ('사회', 484),
#  ('보고', 468),
#  ('연출', 458),
#  ('인생', 448),
#  ('연기력', 433),
#  ('소름', 401),
#  ('히스', 380),
#  ('그냥', 366),
#  ('하나', 336),
#  ('장면', 335),
#  ('레저', 328),
#  ('몰입', 323),
#  ('처음', 322),
#  ('이해', 311),
#  ('광기', 295),
#  ('배우', 289),
#  ('스토리', 288),
#  ('정도', 288),
#  ('자체', 275),
#  ('내내', 273),
#  ('세상', 267),
#  ('명작', 258),
#  ('탄생', 258),
#  ('웃음', 247),
#  ('현실', 245),
#  ('느낌', 238),
#  ('우리', 238),
#  ('계단', 236),
#  ('음악', 236),
#  ('공감', 214),
#  ('인간', 208),
#  ('작품', 206),
#  ('표현', 206),
#  ('한번', 199),
#  ('마지막', 193),
#  ('올해', 190),
#  ('가장', 189),
#  ('모든', 189),
#  ('마음', 184),
#  ('감정', 184),
#  ('배트맨', 181),
#  ('과정', 181),
#  ('다시', 179),
#  ('모두', 177),
#  ('역대', 173),
#  ('누구', 170),
#  ('다크나이트', 168),
#  ('기분', 162),
#  ('모습', 154),
#  ('예술', 152),
#  ('여운', 151),
# ...

# %%
import matplotlib.pyplot as plt
import platform

# 폰트설정
from matplotlib import font_manager, rc
if platform.system()  == 'Darwin':
    rc('font',family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print('unknown system')
    
# %matplotlib inline

# %%
data = word.vocab().most_common(600)
tmp_data = dict(data)

wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                     relative_scaling = 0.2,
                     background_color='white',
                     ).generate_from_frequencies(tmp_data)

plt.figure(figsize=(50,50))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import numpy as np
from PIL import Image
from wordcloud import STOPWORDS

movie_coloring = np.array(Image.open('./movie_image.jpg'))

# %%
from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(movie_coloring)

# %%
plt.figure(figsize=(12,12))
plt.imshow(movie_coloring, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                     relative_scaling = 0.08, mask=movie_coloring,
                     background_color='white',max_words = 4000#,min_font_size=1,max_font_size=20,random_state=50
                     ).generate_from_frequencies(tmp_data)

plt.figure(figsize=(15,15))
plt.imshow(wordcloud.recolor(color_func=image_colors),interpolation='bilinear')
plt.axis('off')
plt.savefig("word_cloud.png", format="png")
plt.show()
